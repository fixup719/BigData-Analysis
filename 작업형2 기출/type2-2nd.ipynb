# %% [markdown]
# # 작업형2
# - 빅데이터 분석기사 2회 실기
# - 데이터 다운로드 : https://www.kaggle.com/prachi13/customer-analytics
# - 데이터 파일 명 : Train.csv (파일명이 다를 경우 파일명을 수정해주세요)
# - (데이터가 삭제될 시 수업노트에 유사 데이터 셋을 올려두겠습니다)
#
#
# ## 제품 배송 시간에 맞춰 배송되었는지 예측모델 만들기
# - 제공된 데이터
#     - X_train.csv
#     - y_train.csv
#     - X_test.csv
#
# - 학습용 데이터 (X_train, y_train)을 이용하여 배송 예측 모형을 만든 후, 이를 평가용 데이터(X_test)에 적용하여 얻은 예측(시간에 맞춰 도착하지 않을 확률)값을 다음과 같은 형식의 CSV파일로 생성하시오(제출한 모델의 성능은 ROC-AUC 평가지표에 따라 채점)
# - 0 정시 도착, 1 정시 도착하지 않음
#
# ```
# ID,Reached.on.Time_Y.N
# 3500,0.267
# 3501,0.578
# 3502,0.123
#
# ```
#
# - 출력을 원하실 경우 print() 함수 활용
# - 예시) print(df.head())
# - getcwd(), chdir() 등 작업 폴더 설정 불필요
# - 파일 경로 상 내부 드라이브 경로(C: 등) 접근 불가
#
# - 데이터 파일 읽기 예제
#
# ```
# # 데이터 불러오기
# import pandas as pd
# X_test = pd.read_csv("data/X_test.csv")
# X_train = pd.read_csv("data/X_train.csv")
# y_train = pd.read_csv("data/y_train.csv")
# ```
#
# - csv파일 생성 예시
#
# ```
# pd.DataFrame({'ID': X_test['cust_id'], 'Reached.on.Time_Y.N': pred}).to_csv('003000000.csv', index=False)
# ```

# %%
# 시험환경 세팅 3개 파일 생성 (코드 변경 X)
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

def exam_data_load(df, target, id_name="", null_name=""):
    if id_name == "":
        df = df.reset_index().rename(columns={"index": "id"})
        id_name = 'id'
    else:
        id_name = id_name

    if null_name != "":
        df[df == null_name] = np.nan

    X_train, X_test = train_test_split(df, test_size=0.2, random_state=2022)
    y_train = X_train[[id_name, target]]
    X_train = X_train.drop(columns=[target])

    y_test = X_test[[id_name, target]]
    X_test = X_test.drop(columns=[target])
    return X_train, X_test, y_train, y_test

df = pd.read_csv("Train.csv") # 파일명이 다를 경우 파일명을 수정해주세요
X_train, X_test, y_train, y_test = exam_data_load(df, target='Reached.on.Time_Y.N', id_name='ID')
X_train.to_csv("X_train.csv", index=False)
y_train.to_csv("y_train.csv", index=False)
X_test.to_csv("X_test.csv", index=False)

# %%
# 데이터 불러오기
import pandas as pd
X_test = pd.read_csv("X_test.csv")
X_train = pd.read_csv("X_train.csv")
y_train = pd.read_csv("y_train.csv")

X_train.shape, y_train.shape, X_test.shape
# Out:
# ((8799, 11), (8799, 2), (2200, 11))

# %% [markdown]
# ## EDA

# %%
X_train.head()
# Out:
#       ID Warehouse_block  ... Discount_offered  Weight_in_gms
# 0   8440               B  ...                4           4795
# 1  10849               D  ...               10           5565
# 2   9478               B  ...                9           4425
# 3   2968               B  ...               61           3140
# 4   6964               B  ...                9           4766
#
# [5 rows x 11 columns]

# %%
y_train.head()
# Out:
#       ID  Reached.on.Time_Y.N
# 0   8440                    1
# 1  10849                    0
# 2   9478                    1
# 3   2968                    1
# 4   6964                    0

# %%
# 결측치 확인 train
X_train.isnull().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# dtype: int64

# %%
# 결측치 확인 test
X_test.isnull().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# dtype: int64

# %%
# 타겟(레이블) 확인 0 정시 도착, 1 정시 도착하지 않음
y_train['Reached.on.Time_Y.N'].value_counts()
# Out:
# 1    5236
# 0    3563
# Name: Reached.on.Time_Y.N, dtype: int64

# %%
# 데이터 타입 확인
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8799 entries, 0 to 8798
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   8799 non-null   int64
#  1   Warehouse_block      8799 non-null   object
#  2   Mode_of_Shipment     8799 non-null   object
#  3   Customer_care_calls  8799 non-null   int64
#  4   Customer_rating      8799 non-null   int64
#  5   Cost_of_the_Product  8799 non-null   int64
#  6   Prior_purchases      8799 non-null   int64
#  7   Product_importance   8799 non-null   object
#  8   Gender               8799 non-null   object
#  9   Discount_offered     8799 non-null   int64
#  10  Weight_in_gms        8799 non-null   int64
# dtypes: int64(7), object(4)
# memory usage: 756.3+ KB

# %%
# 기초 통계 획인
X_train.describe()
# Out:
#                  ID  Customer_care_calls  ...  Discount_offered  Weight_in_gms
# count   8799.000000          8799.000000  ...       8799.000000    8799.000000
# mean    5514.696556             4.051369  ...         13.293215    3633.145130
# std     3175.107399             1.141739  ...         16.112977    1637.717073
# min        1.000000             2.000000  ...          1.000000    1001.000000
# 25%     2749.500000             3.000000  ...          4.000000    1837.000000
# 50%     5519.000000             4.000000  ...          7.000000    4152.000000
# 75%     8253.000000             5.000000  ...         10.000000    5055.000000
# max    10999.000000             7.000000  ...         65.000000    7846.000000
#
# [8 rows x 7 columns]

# %%
# 기초 통계 획인 object
X_train.describe(include='object')
# Out:
#        Warehouse_block Mode_of_Shipment Product_importance Gender
# count             8799             8799               8799   8799
# unique               5                3                  3      2
# top                  F             Ship                low      F
# freq              2929             5972               4225   4450

# %%
# 기초 통계 획인 object
X_test.describe(include='object')
# Out:
#        Warehouse_block Mode_of_Shipment Product_importance Gender
# count             2200             2200               2200   2200
# unique               5                3                  3      2
# top                  F             Ship                low      M
# freq               737             1490               1072   1105

# %%
# [Tip] object 타입 고유값 개수 확인
X_train[['Warehouse_block', 'Mode_of_Shipment', 'Product_importance', 'Gender']].nunique()
# Out:
# Warehouse_block       5
# Mode_of_Shipment      3
# Product_importance    3
# Gender                2
# dtype: int64

# %%
# X데이터와 y데이터 합치기
df = pd.concat([X_train, y_train['Reached.on.Time_Y.N']],axis=1)
df.head(1)
# Out:
#      ID Warehouse_block  ... Weight_in_gms  Reached.on.Time_Y.N
# 0  8440               B  ...          4795                    1
#
# [1 rows x 12 columns]

# %%
# idea? 할인율이 도착에 영향을 미칠까?
cond = df['Discount_offered'] > 10
sum(cond)
# Out:
# 2104

# %%
sum(df[cond]['Reached.on.Time_Y.N'])
# Out:
# 2104

# %% [markdown]
# ## 데이터 전처리 및 피처엔지니어링

# %%
# 라벨 인코딩
from sklearn.preprocessing import LabelEncoder

cols = X_train.select_dtypes(include='object').columns
print(cols)

for col in cols:
    le = LabelEncoder()
    X_train[col] = le.fit_transform(X_train[col])
    X_test[col] = le.transform(X_test[col])

# col = 'Warehouse_block'
# le = LabelEncoder()
# X_train[col] = le.fit_transform(X_train[col])
# X_test[col] = le.transform(X_test[col])

# col = 'Mode_of_Shipment'
# le = LabelEncoder()
# X_train[col] = le.fit_transform(X_train[col])
# X_test[col] = le.transform(X_test[col])

# col = 'Product_importance'
# le = LabelEncoder()
# X_train[col] = le.fit_transform(X_train[col])
# X_test[col] = le.transform(X_test[col])

# col = 'Gender'
# le = LabelEncoder()
# X_train[col] = le.fit_transform(X_train[col])
# X_test[col] = le.transform(X_test[col])

X_train.head()
# Out:
# Index(['Warehouse_block', 'Mode_of_Shipment', 'Product_importance', 'Gender'], dtype='object')
#       ID  Warehouse_block  ...  Discount_offered  Weight_in_gms
# 0   8440                1  ...                 4           4795
# 1  10849                3  ...                10           5565
# 2   9478                1  ...                 9           4425
# 3   2968                1  ...                61           3140
# 4   6964                1  ...                 9           4766
#
# [5 rows x 11 columns]

# %%
# trainID 삭제, testID 값만 옮겨둠
# X_train_id = X_train.pop('ID')
X_train = X_train.drop('ID', axis=1)
X_test_id = X_test.pop('ID')
X_test.head()
# Out:
#    Warehouse_block  Mode_of_Shipment  ...  Discount_offered  Weight_in_gms
# 0                2                 2  ...                 2           4271
# 1                1                 2  ...                 4           1630
# 2                2                 2  ...                 5           5216
# 3                2                 0  ...                10           4347
# 4                1                 2  ...                 3           2169
#
# [5 rows x 10 columns]

# %% [markdown]
# ## 모델 및 평가

# %%
# 라이브러리 불러오기
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.metrics import roc_auc_score

# %%
# 검증 데이터 분리
from sklearn.model_selection import train_test_split
X_tr,X_val,y_tr,y_val = train_test_split(
                                         X_train,
                                         y_train['Reached.on.Time_Y.N'],
                                         test_size=0.2,
                                         random_state=2021
                                         )
X_tr.shape, X_val.shape, y_tr.shape, y_val.shape
# Out:
# ((7039, 10), (1760, 10), (7039,), (1760,))

# %%
# 로지스틱 회귀
model = LogisticRegression(random_state=2022)
model.fit(X_tr, y_tr)
pred = model.predict_proba(X_val)
print(roc_auc_score(y_val, pred[:,1]))
# Out:
# 0.7084055061812334

# %%
# 의사결정나무
model = DecisionTreeClassifier(random_state=2022)
model.fit(X_tr, y_tr)
pred = model.predict_proba(X_val)
print(roc_auc_score(y_val, pred[:,1]))
# Out:
# 0.6321275746145835

# %%
# 랜덤포레스트
model = RandomForestClassifier(random_state=2022)
model.fit(X_tr, y_tr)
pred = model.predict_proba(X_val)
print(roc_auc_score(y_val, pred[:,1]))
# Out:
# 0.7279225281811363

# %%
# XGBOOST
model = XGBClassifier(random_state=2022)
model.fit(X_tr, y_tr)
pred = model.predict_proba(X_val)
print(roc_auc_score(y_val, pred[:,1]))
# Out:
# 0.7370938759652275

# %% [markdown]
# ## 예측 및 제출

# %%
# 예측
pred = model.predict_proba(X_test)
pred
# Out:
# array([[0.5864563 , 0.4135437 ],
#        [0.51828134, 0.48171863],
#        [0.5956555 , 0.4043445 ],
#        ...,
#        [0.61031115, 0.38968882],
#        [0.58652174, 0.41347829],
#        [0.59572583, 0.40427417]], dtype=float32)

# %%
# 데이터프레임 만들기
submit = pd.DataFrame({
                        "ID": X_test_id,
                        "Reached.on.Time_Y.N": pred[:,1]
                      })

# %%
# 데이터 확인
submit.head()
# Out:
#       ID  Reached.on.Time_Y.N
# 0   8285             0.413544
# 1  10192             0.481719
# 2   8675             0.404344
# 3   5753             0.436857
# 4    448             0.947564

# %%
# CSV파일 만들기
submit.to_csv('20220217.csv', index=False)  ## 수험번호.csv

# %% [markdown]
# ##  제대로 제출 되었는지 확인

# %%
pd.read_csv("20220217.csv")
# Out:
#          ID  Reached.on.Time_Y.N
# 0      8285             0.413544
# 1     10192             0.481719
# 2      8675             0.404344
# 3      5753             0.436857
# 4       448             0.947564
# ...     ...                  ...
# 2195   7193             0.431239
# 2196   4445             0.315444
# 2197   7390             0.389689
# 2198   9977             0.413478
# 2199   5696             0.404274
#
# [2200 rows x 2 columns]

# %% [markdown]
# ## 체점
# - 수험자는 알 수 없는 부분임

# %%
you = pd.read_csv("20220217.csv")
print("당신의 score는?:",roc_auc_score(y_test['Reached.on.Time_Y.N'], you['Reached.on.Time_Y.N']))
# Out:
# 당신의 score는?: 0.7396611568179091

# %%
# 당신의 score는?: 0.7396611568179091
