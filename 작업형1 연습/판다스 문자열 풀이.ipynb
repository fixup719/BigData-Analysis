# %% [markdown]
# ## 문자열(심화)

# %%
# import pandas as pd
# df = pd.DataFrame({'A': ['블루베리 스무디', '딸기 스무디', '딸기 바나나 스무디'],
#                    'B': [10, 20, 30],
#                    'C': ['추천/신메뉴', '신메뉴/할인', '사이즈업/추천'],
#                    'D': ['ab cd', 'AB CD', 'ab cd']
#                    })
# df

import pandas as pd
df = pd.DataFrame({
    'A': ['블루베리 스무디', '딸기 스무디', '딸기 바나나 스무디'],
    'B': [10, 20, 30],
    'C': ['추천/신메뉴', '신메뉴/할인', '사이즈업/추천'],
    'D': ['ab cd', 'AB CD', 'ab cd']
})
df
# Out:
#             A   B        C      D
# 0    블루베리 스무디  10   추천/신메뉴  ab cd
# 1      딸기 스무디  20   신메뉴/할인  AB CD
# 2  딸기 바나나 스무디  30  사이즈업/추천  ab cd

# %%
# replace, 전체 문자가 일치해야 변경
# df['A'] = df['A'].replace('스무디', '에이드')
# df


# replace : 전체 문자열이 일치해야만 변경 가능
# df['A'].replace('스무디', '에이드') X
# Out:
# 0      블루베리 스무디
# 1        딸기 스무디
# 2    딸기 바나나 스무디
# Name: A, dtype: object

# %%
# str.replace, 일부 일치하는 문자 변경
# df['A'] = df['A'].str.replace('스무디', '에이드')
# df

# str.replace -> 일분 문자열 일치 변경
df['A'] = df['A'].str.replace('스무디', '에이드')
df
# Out:
#             A   B        C      D
# 0    블루베리 에이드  10   추천/신메뉴  ab cd
# 1      딸기 에이드  20   신메뉴/할인  AB CD
# 2  딸기 바나나 에이드  30  사이즈업/추천  ab cd

# %%
# replace 데이터프레임
# df.replace('블루베리 에이드', '청포도 에이드')

# replace는 데이터 프레임 기준
df['A'] = df['A'].replace('블루베리 에이드', '청포도 에이드')
df
# Out:
#             A   B        C      D
# 0     청포도 에이드  10   추천/신메뉴  ab cd
# 1      딸기 에이드  20   신메뉴/할인  AB CD
# 2  딸기 바나나 에이드  30  사이즈업/추천  ab cd

# %%
# 숫자 변경
# df['B'] = df['B'].replace(10, 100)
# df

# 숫자 변경하기 -> 10을 100으로
df['B'] = df['B'].replace(10, 100)
df
# Out:
#             A    B        C      D
# 0     청포도 에이드  100   추천/신메뉴  ab cd
# 1      딸기 에이드   20   신메뉴/할인  AB CD
# 2  딸기 바나나 에이드   30  사이즈업/추천  ab cd

# %%
# 숫자 변경(str.replace)
# df['B'] = df['B'].str.replace(10, 100)
# df

# str.replace로 변경 불가 -> string 타입만 가능
# df['B'] = df['B'].str.replace(10, 100)
# df['B']

# %%
# 어절 나누기
# df['A'].str.split()

# 어절 나누기 -> split()
pd.DataFrame(df['A'].str.split().str[0])
# Out:
#      A
# 0  청포도
# 1   딸기
# 2   딸기

# %%
# 어절 나눈 후 첫 번째 값
df['A'].str.split().str[0]
# Out:
# 0    청포도
# 1     딸기
# 2     딸기
# Name: A, dtype: object

# %%
# 어절 나눈 후 첫 번째 값을 새로운 컬럼으로 대입
# df['E'] = df['A'].str.split().str[0]
# df


# 어절 나눈 걸 새로운 칼럼으로 넣기
df['NEW'] = df['A'].str.split().str[0]
df
# Out:
#             A    B        C      D  NEW
# 0     청포도 에이드  100   추천/신메뉴  ab cd  청포도
# 1      딸기 에이드   20   신메뉴/할인  AB CD   딸기
# 2  딸기 바나나 에이드   30  사이즈업/추천  ab cd   딸기

# %%
# 어절 나누기(/)
# df['C'].str.split('/')


# / 기준 어절 나누기
df['C'].str.split('/')
# Out:
# 0     [추천, 신메뉴]
# 1     [신메뉴, 할인]
# 2    [사이즈업, 추천]
# Name: C, dtype: object

# %%
# 특정 문자 찾기 (contains)
# df['A'].str.contains('딸기')

# 특정 문자 찾기 contains
df['A'].str.contains('딸기')
# Out:
# 0    False
# 1     True
# 2     True
# Name: A, dtype: bool

# %%
# 특정 문자 찾은 후 새컬럼에 대입 (contains)
# df['is딸기'] = df['A'].str.contains('딸기')
# df

df['is딸기'] = df['A'].str.contains('딸기')
df
# Out:
#             A    B        C      D  NEW   is딸기
# 0     청포도 에이드  100   추천/신메뉴  ab cd  청포도  False
# 1      딸기 에이드   20   신메뉴/할인  AB CD   딸기   True
# 2  딸기 바나나 에이드   30  사이즈업/추천  ab cd   딸기   True

# %%
# 데이터
# menu = pd.Series(['맛난버거 세트', '매운 치킨버거', '더블 치즈버거'])
menu = pd.Series(['맛난버거 세트', '매운 치킨버거', '더블 치즈버거'])
menu
# Out:
# 0    맛난버거 세트
# 1    매운 치킨버거
# 2    더블 치즈버거
# dtype: object

# %%
# 특정 값이 있는지 확인하기 (isin)
# menu.isin(['맛난버거 세트', '더블 치즈버거'])

# 특정 갑 여부 확인 isin -> 여러개 가능
# menu.isin(['맛난버거 세트', '더블 치즈버거'])

df['A'].isin(['딸기 에이드'])
# Out:
# 0    False
# 1     True
# 2    False
# Name: A, dtype: bool

# %%
# 특정 단어가 있는지 확인하기 (isin)
# menu.isin(['세트'])

# 특정 단어 있는지 확인 -> str.contains
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
# 특정 단어가 있는지 확인하기 (contains)
# menu.str.contains('세트')

df['A'].str.contains('에이드')
# Out:
# 0    True
# 1    True
# 2    True
# Name: A, dtype: bool

# %%
# 문자 길이
# df['A'].str.len()

# 문자 길이 str.len()
df['A'].str.len()
# df
# Out:
# 0     7
# 1     6
# 2    10
# Name: A, dtype: int64

# %%
# 대소문자 구분
# 'AB cd' == 'ab CD'

# 대소문자 구분함
df = pd.DataFrame({
    'A': ['블루베리 스무디', '딸기 스무디', '딸기 바나나 스무디'],
    'B': [10, 20, 30],
    'C': ['추천/신메뉴', '신메뉴/할인', '사이즈업/추천'],
    'D': ['ab cd', 'AB CD', 'ab cd']
})

df
# Out:
#             A   B        C      D
# 0    블루베리 스무디  10   추천/신메뉴  ab cd
# 1      딸기 스무디  20   신메뉴/할인  AB CD
# 2  딸기 바나나 스무디  30  사이즈업/추천  ab cd

# %%
# 소문자로 변경
# df['D'].str.lower()

# 소문자로 변경
# df['D'] = df['D'].str.lower()
# df['D'] = df['D'].str.lower()
df
# Out:
#             A   B        C      D
# 0    블루베리 스무디  10   추천/신메뉴  ab cd
# 1      딸기 스무디  20   신메뉴/할인  ab cd
# 2  딸기 바나나 스무디  30  사이즈업/추천  ab cd

# %%
# 대문자로 변경
# df['D'].str.upper()

# df['D'] = df['D'].str.upper()
df
# Out:
#             A   B        C      D
# 0    블루베리 스무디  10   추천/신메뉴  AB CD
# 1      딸기 스무디  20   신메뉴/할인  AB CD
# 2  딸기 바나나 스무디  30  사이즈업/추천  AB CD

# %%
df2 = pd.DataFrame({'A': ['블루베리 스무디', '딸기 스무디', '딸기 바나나 스무디'],
                   'B': [10, 20, 30],
                   'C': ['추천/신메뉴', '신메뉴/할인', '사이즈업/추천'],
                   'D': ['ab cd', 'AB CD', 'ab cd ']
                   })

# %%
# AB CD와 같은가?
# df2['D'] = df2['D'].str.upper()
# df2['D'] == 'AB CD'

# df2['D'] == 'AB CD'

# df2['D'] = df2['D'].str.upper()
df2['D'] == 'AB CD'

df2
# Out:
#             A   B        C       D
# 0    블루베리 스무디  10   추천/신메뉴   AB CD
# 1      딸기 스무디  20   신메뉴/할인   AB CD
# 2  딸기 바나나 스무디  30  사이즈업/추천  AB CD

# %%
# 공백 제거
# df2['D'] = df2['D'].str.replace(" ","")
# df2

# 공백 제거
df2['D'] = df2['D'].str.replace(" ", "")
df2
# Out:
#             A   B        C     D
# 0    블루베리 스무디  10   추천/신메뉴  ABCD
# 1      딸기 스무디  20   신메뉴/할인  ABCD
# 2  딸기 바나나 스무디  30  사이즈업/추천  ABCD

# %%
# 슬라이싱(str)
# df2['D'].str[:2]

# AB만 출력
df2['D'].str[:2]
# Out:
# 0    AB
# 1    AB
# 2    AB
# Name: D, dtype: object

# %%
# 슬라이싱
df2['D'][:2]
# Out:
# 0    ABCD
# 1    ABCD
# Name: D, dtype: object

# %%
# 데이터
df = pd.DataFrame({'date':['2024년 3월', '2024년 4월', '2025년 5월']})

# %%
# 연도
# df['date'].str[:4]

df['date'].str[:4]
# Out:
# 0    2024
# 1    2024
# 2    2025
# Name: date, dtype: object

# %%
# 월
# df['date'].str[6:7]

# df['date'].str[]
# Out:
# 0    3
# 1    4
# 2    5
# Name: date, dtype: object
