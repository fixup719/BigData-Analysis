# %% [markdown]
# # 판다스
# - 수업노트에 링크 첨부: https://bit.ly/3xbu0y5
# - 구글드라이브 복사 후 코딩 시작

# %% [markdown]
# # 데이터 핸들링을 위한 판다스 기초1

# %%
# 학습 전 반드시 실행: csv파일 (data.csv) 생성
# import pandas as pd
# data = {
#     "메뉴":['아메리카노','카페라떼','카페모카', '바닐라라떼', '녹차', '초코라떼', '바닐라콜드브루'],
#     "가격":[4100, 4600, 4600, 5100, 4100, 5000, 5100],
#     "할인율":[0.5, 0.1, 0.2, 0.3, 0, 0, 0],
#     "칼로리":[10, 180, 420, 320, 20, 500, 400],
# }
# data = pd.DataFrame(data)
# data.to_csv('data.csv', index=False)

# data.csv 파일 생성하기 => 카페 메뉴, 가격, 할인율, 칼로리 칼럼 생성
import pandas as pd
data = {
    "메뉴" : ['아메리카노', '카페라떼', '자바칩프라푸치노', '자몽허니블랙티', '말차프라푸치노'],
    "가격" : [3500, 4000, 6000, 5500, 6000],
    "할인율" : [0.3, 0.4, 0.2, 0.1, 0.25],
    "칼로리" : [10, 100, 555, 175, 340],
}
# 데이터프레임으로 만들고 담기 pd.DataFrame(원본데이터)
cafeData = pd.DataFrame(data)
# csv파일로 생성하기 변환하려는 데이터프레임.to_csv('파일명', index=False)
cafeData.to_csv('cafeData.csv', index=False)

# %% [markdown]
# ## 라이브러리 불러오기

# %%
# 판다스 라이브러리
# import pandas as pd

# 판다스 라이브러리 불러오기
# import pandas as pd

# %% [markdown]
# ## 데이터 불러오기

# %%
# 데이터 불러오기
# pd.read_csv('data.csv')
# pd.read_csv('data.csv')

# 데이터 불러오기
pd.read_csv('cafeData.csv')
# Out:
#          메뉴    가격   할인율  칼로리
# 0     아메리카노  3500  0.30   10
# 1      카페라떼  4000  0.40  100
# 2  자바칩프라푸치노  6000  0.20  555
# 3   자몽허니블랙티  5500  0.10  175
# 4   말차프라푸치노  6000  0.25  340

# %%
# 데이터 불러와서 변수에 담기
# df = pd.read_csv('data.csv')

# 데이터 불러와서 변수에 담기
# df = pd.read_csv('data.csv')

# 불러온 데이터 변수에 담기 pd.read_csv('파일명)
# cdf = pd.read_csv('cafeData.csv')
cdf = pd.read_csv('cafeData.csv')

# %%
# 데이터 샘플 확인: 앞에서 부터 n개 (기본 5개)
# df.head(2)

# 데이터 샘플 확인 : 앞에서 부터 n개 (기본 5개)
# df.head(1)

# 데이터 샘플 확인 -> 위에서부터 3개 조회하기
cdf.head(3)
# Out:
#          메뉴    가격  할인율  칼로리
# 0     아메리카노  3500  0.3   10
# 1      카페라떼  4000  0.4  100
# 2  자바칩프라푸치노  6000  0.2  555

# %%
# 데이터 샘플 확인: 뒤에서 부터 n개 (기본 5개)
# df.tail(3)

# 데이터 샘플 학인 : 뒤에서 부터 n개 (기본 5개)
# df.tail(3)

# 아래서부터 2개
cdf.tail(2)
# Out:
#         메뉴    가격   할인율  칼로리
# 3  자몽허니블랙티  5500  0.10  175
# 4  말차프라푸치노  6000  0.25  340

# %% [markdown]
# ## 데이터 프레임과 시리즈

# %%
# 시리즈 만들기 (문자열)
# menu = pd.Series(['아아', '아라', '바콜'])
# menu

# 시리즈 만들기 (문자열)
# menu = pd.Series(['아아', '아라', '바콜'])
# menu

# 시리즈 : 데이터프레임 하위 자료형 -> 1개의 열이 시리즈가 됨, 다수의 시리즈가 모여 데이터 프레임 형성
myMenu = pd.Series(['자몽허니블랙티', '자바칩프라푸치노', '말차프라푸치노'])
myMenu
# Out:
# 0     자몽허니블랙티
# 1    자바칩프라푸치노
# 2     말차프라푸치노
# dtype: object

# %%
# 시리즈 만들기(정수형)
# price = pd.Series([2000, 3000, 4000])
# price

# 시리즈 만들기(정수형)
# price = pd.Series([2000,3000,4000])
# price

# 정수형 시리즈 만들기
price = pd.Series([4500, 6500, 6000])
price
# Out:
# 0    4500
# 1    6500
# 2    6000
# dtype: int64

# %%
# 데이터 프레임 만들기 pd.DataFrame({"컬럼명":데이터})
# pd.DataFrame({
#     "menu" : menu,
#     "price" : price
# })

# 데이터 프레임 만들기 => pd.DataFrame({"칼럼명" : 데이터})
# pd.DataFrame({
#     "menu" : menu,
#     "price" : price,
# })

# 아까 위에서 만든 시리즈로 데이터 프레임 만들기  => pd.DataFrame
data = pd.DataFrame({
    "myMenu" : myMenu,
    "price" : price,
})

data
# Out:
#      myMenu  price
# 0   자몽허니블랙티   4500
# 1  자바칩프라푸치노   6500
# 2   말차프라푸치노   6000

# %%
# 데이터 프레임 만들기 pd.DataFrame({"컬럼명":데이터})
# data = {
#     "메뉴":['아메리카노','카페라떼','카페모카'],
#     "가격":[4100,4600,4600],
#     "할인율":[0.5, 0.1, 0.2],
#     "칼로리":[10, 180, 420],
# }
# cafe = pd.DataFrame(data)
# cafe

# 데이터 프레임 만들기 pd.DataFrame({"칼럼명":데이터})
# data = {
#     "메뉴" : ['아메리카노', '카페라떼', '카페모카'],
#     "가격" : [4100, 4600, 2000],
#     "할인율" : [0.1, 0.2, 0.3],
#     "칼로리" : [100, 200, 300],
# }

# cafe = pd.DataFrame(data)
# cafe

#시리즈 말고 직접 만들어보기
data = {
    "나의 메뉴" : ['자몽허니블랙티', '자바칩프라푸치노', '말차프라푸치노'],
    "가격" : [4500, 6500, 6000],
    "할인율" : [0.3, 0.2, 0.15],
    "칼로리" : [175, 640, 340],
}

mcdf = pd.DataFrame(data)
mcdf
# Out:
#       나의 메뉴    가격   할인율  칼로리
# 0   자몽허니블랙티  4500  0.30  175
# 1  자바칩프라푸치노  6500  0.20  640
# 2   말차프라푸치노  6000  0.15  340

# %%
# 시리즈 선택 (가격)
# df['메뉴']

# 시리즈 선택 (메뉴)
# df['메뉴']

# 시리즈 선택하기 -> 나의메뉴 열 선택
mcdf['나의 메뉴']
# Out:
# 0     자몽허니블랙티
# 1    자바칩프라푸치노
# 2     말차프라푸치노
# Name: 나의 메뉴, dtype: object

# %%
# 데이터프레임 선택 (가격)
# df[['가격', '할인율']]

# 데이터 프레임 선택
# df[['가격']]

# 나의 메뉴 시리즈를 데이터 프레임으로 조회
mcdf[['나의 메뉴']]
# Out:
#       나의 메뉴
# 0   자몽허니블랙티
# 1  자바칩프라푸치노
# 2   말차프라푸치노

# %%
# 데이터 프레임 type 확인
# type(df)

# 데이터 프레임 type 확인
# type(df)

# 데이터 프레임 type 확인
type(mcdf)
# Out:
# pandas.core.frame.DataFrame

# %%
# 시리즈 type 확인
# type(df['가격'])

# 나의메뉴 시리즈 type 확인
type(mcdf['나의 메뉴'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## EDA (탐색적 데이터 분석)

# %%
# 데이터 불러오기 (에러가 뜬다면 가장 첫번째 셀, csv 파일을 생성하는 코드 실행)
# df = pd.read_csv('data.csv')

cdf = pd.read_csv('cafeData.csv')
cdf
# Out:
#          메뉴    가격   할인율  칼로리
# 0     아메리카노  3500  0.30   10
# 1      카페라떼  4000  0.40  100
# 2  자바칩프라푸치노  6000  0.20  555
# 3   자몽허니블랙티  5500  0.10  175
# 4   말차프라푸치노  6000  0.25  340

# %%
# 데이터 프레임 크기 (행, 컬럼)
# df.shape

# 데이터 프레임 크기(행, 열)
cdf.shape
# Out:
# (5, 4)

# %%
# 컬럼 형태(type)
# df.info()

# 컬럼 형태 => info
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      5 non-null      object
#  1   가격      5 non-null      int64
#  2   할인율     5 non-null      float64
#  3   칼로리     5 non-null      int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 288.0+ bytes

# %%
# 기초 통계
# df.describe()

# 기초 통게 조회하기
cdf.describe()

cdf
# Out:
#          메뉴    가격   할인율  칼로리
# 0     아메리카노  3500  0.30   10
# 1      카페라떼  4000  0.40  100
# 2  자바칩프라푸치노  6000  0.20  555
# 3   자몽허니블랙티  5500  0.10  175
# 4   말차프라푸치노  6000  0.25  340

# %%
# 기초 통계 (object)
# df.describe(include='O')
cdf.describe(include='object')

#count: 데이터의 개수
#unique: 고윳값의 수(nunique의 결과와 같음)
#top: 가장 많이 등장하는 value
#freq: 전체 데이터에서 top에 나온 value의 개수
# Out:
#            메뉴
# count       5
# unique      5
# top     아메리카노
# freq        1

# %%
# 상관관계
# 코랩에서 판다스 버전이 업데이트되어 일부 함수에 `numeric_only=True` 를 설정해야 합니다.
# 이 설정은 데이터프레임에서 숫자 형태의 데이터만 선택하도록 지정합니다. (단, 시험환경 버전은 설정 필요 없음)
# df.corr()
# df.corr(numeric_only=True)

#상관관계 조회
cdf.corr(numeric_only=True)
# Out:
#            가격       할인율       칼로리
# 가격   1.000000 -0.667424  0.857992
# 할인율 -0.667424  1.000000 -0.399366
# 칼로리  0.857992 -0.399366  1.000000

# %%
# 중복 값이 있는 데이터 생성
# car = {
#     "car":['Sedan','SUV','Sedan','SUV','SUV','SUV','Sedan','Sedan','Sedan','Sedan','Sedan'],
#     "size":['S','M','S','S','M','M','L','S','S', 'M','S']
# }
# car = pd.DataFrame(car)
# car.head(3)

# 중복 값이 있는 데이터 생성하기
car = {
    "name" : ['SUV', 'BMW', 'SUV', 'SEDAN', 'VOLVO', 'SONATA', 'K5', 'OUDI', 'BMW', 'BMW'],
    "size" : ['L', 'M', 'L', 'S', 'L', 'S', 'M', 'M', 'M', 'M']
}

cardf = pd.DataFrame(car)
cardf.head(5)
# Out:
#     name size
# 0    SUV    L
# 1    BMW    M
# 2    SUV    L
# 3  SEDAN    S
# 4  VOLVO    L

# %%
# 항목 종류 수
# car.nunique()

# 항목 종류 수
cardf.nunique()
# Out:
# name    7
# size    3
# dtype: int64

# %%
# 항목 종류
# car['car'].unique()

#항목 종류 -> series로 조회해야함
cardf['name'].unique()
# Out:
# array(['SUV', 'BMW', 'SEDAN', 'VOLVO', 'SONATA', 'K5', 'OUDI'],
#       dtype=object)

# %%
# car['size'].unique()
cardf['size'].unique()
# Out:
# array(['L', 'M', 'S'], dtype=object)

# %%
# 항목별 개수 (car)
# car['car'].value_counts()

# 항목별 개수 출력
# cardf['name'].value_counts()
cardf['name'].value_counts()
# Out:
# name
# BMW       3
# SUV       2
# SEDAN     1
# VOLVO     1
# SONATA    1
# K5        1
# OUDI      1
# Name: count, dtype: int64

# %%
# 항목별 개수 (size)
car['size'].value_counts()
# Out:
# size
# S    6
# M    4
# L    1
# Name: count, dtype: int64

# %% [markdown]
# ## 자료형 변환

# %%
# 데이터 프레임 만들기 (할인율과 칼로리 -> 문자열)
# data = {
#     "메뉴":['아메리카노', '카페라떼', '카페모카', '바닐라콜드브루'],
#     "가격":[4100, 4600, 4600, 5100],
#     "할인율":['0.5', '0.1', '0.2', '0.3'],
#     "칼로리":[10,180,420,320],
# }
# df = pd.DataFrame(data)
# df.info()

cdf
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      5 non-null      object
#  1   가격      5 non-null      int64
#  2   할인율     5 non-null      float64
#  3   칼로리     5 non-null      int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 288.0+ bytes

# %%
# 자료형 변환 / astype /  object -> float
# df['할인율'] = df['할인율'].astype('float')

# 자료형 변환
cdf['할인율'] = cdf['할인율'].astype('object')

# %%
# 자료형 확인
# cdf.info()

# cdf

cdf['할인율'] = cdf['할인율'].astype('float')
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      5 non-null      object
#  1   가격      5 non-null      int64
#  2   할인율     5 non-null      float64
#  3   칼로리     5 non-null      int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 288.0+ bytes

# %% [markdown]
# ## 새로운 컬럼 추가

# %%
# df

cdf
# Out:
#          메뉴    가격   할인율  칼로리
# 0     아메리카노  3500  0.30   10
# 1      카페라떼  4000  0.40  100
# 2  자바칩프라푸치노  6000  0.20  555
# 3   자몽허니블랙티  5500  0.10  175
# 4   말차프라푸치노  6000  0.25  340

# %%
# 새로운 컬럼 추가 (값은 0)
# df['new'] = 0
# df

# 새로운 칼럼 추가 (값은 0으로)
cdf['새칼럼'] = 0
cdf
# Out:
#          메뉴    가격   할인율  칼로리  새칼럼
# 0     아메리카노  3500  0.30   10    0
# 1      카페라떼  4000  0.40  100    0
# 2  자바칩프라푸치노  6000  0.20  555    0
# 3   자몽허니블랙티  5500  0.10  175    0
# 4   말차프라푸치노  6000  0.25  340    0

# %%
# 할인가 컬럼 추가
# df['할인가'] = df['가격'] * (1-df['할인율'])
# df

# 할인가 칼럼 추가
cdf['할인된가격'] = cdf['가격'] * (1 - cdf['할인율'])
cdf
# Out:
#          메뉴    가격   할인율  칼로리  새칼럼   할인된가격
# 0     아메리카노  3500  0.30   10    0  2450.0
# 1      카페라떼  4000  0.40  100    0  2400.0
# 2  자바칩프라푸치노  6000  0.20  555    0  4800.0
# 3   자몽허니블랙티  5500  0.10  175    0  4950.0
# 4   말차프라푸치노  6000  0.25  340    0  4500.0

# %%
# 결측값으로 추가, 원두 컬럼을 만들고 결측값(NaN)으로 대입
# import numpy as np
# df['원두'] = np.nan
# df

# 결측값으로 추가, 원두 칼럼 만들고 결측값(NaN)으로 대입 -> numpy import
import numpy as np
cdf['원두'] = np.nan
cdf
# Out:
#          메뉴    가격   할인율  칼로리  새칼럼   할인된가격  원두
# 0     아메리카노  3500  0.30   10    0  2450.0 NaN
# 1      카페라떼  4000  0.40  100    0  2400.0 NaN
# 2  자바칩프라푸치노  6000  0.20  555    0  4800.0 NaN
# 3   자몽허니블랙티  5500  0.10  175    0  4950.0 NaN
# 4   말차프라푸치노  6000  0.25  340    0  4500.0 NaN

# %% [markdown]
# ## 데이터 삭제

# %% [markdown]
# ### 컬럼 삭제

# %%
# 데이터 삭제
# axis=1:열방향(컬럼) / axis=0:행방향
# df = df.drop('new', 1) # 코랩 판다스 버전이 올라가면서 워닝이 발생함. 따라서 axis사용 권장함
# df = df.drop('new', axis=1)


# 데이터 삭제
# axis = 1 ; 열방향 / axis = 0 : 행방향
cdf = cdf.drop('새칼럼', axis = 1)
cdf
# Out:
#          메뉴    가격   할인율  칼로리   할인된가격  원두
# 0     아메리카노  3500  0.30   10  2450.0 NaN
# 1      카페라떼  4000  0.40  100  2400.0 NaN
# 2  자바칩프라푸치노  6000  0.20  555  4800.0 NaN
# 3   자몽허니블랙티  5500  0.10  175  4950.0 NaN
# 4   말차프라푸치노  6000  0.25  340  4500.0 NaN

# %%
# 데이터 확인
# df.head(2)
# Out:
#       메뉴    가격  할인율  칼로리     할인가  원두
# 0  아메리카노  4100  0.5   10  2050.0 NaN
# 1   카페라떼  4600  0.1  180  4140.0 NaN

# %% [markdown]
# ### 행 삭제

# %%
# 행 삭제
# df = df.drop(1, axis=0)

#특정 행 삭제
# cdf.drop(0, axis = 0)

cdf
# Out:
#          메뉴    가격   할인율  칼로리   할인된가격  원두
# 0     아메리카노  3500  0.30   10  2450.0 NaN
# 1      카페라떼  4000  0.40  100  2400.0 NaN
# 2  자바칩프라푸치노  6000  0.20  555  4800.0 NaN
# 3   자몽허니블랙티  5500  0.10  175  4950.0 NaN
# 4   말차프라푸치노  6000  0.25  340  4500.0 NaN

# %%
# 데이터 확인
df
# Out:
#         메뉴    가격  할인율  칼로리     할인가  원두
# 0    아메리카노  4100  0.5   10  2050.0 NaN
# 2     카페모카  4600  0.2  420  3680.0 NaN
# 3  바닐라콜드브루  5100  0.3  320  3570.0 NaN

# %% [markdown]
# ## CSV 저장하기

# %%
# csv로 저장하기
# df.to_csv('data2.csv', index=False)
# df.to_csv('data2.csv')

# csv로 저장하기
cdf.to_csv('newCafeData.csv', index=False)

# %%
# csv 불러오기
# new_df = pd.read_csv('data2.csv')
# new_df.head()

new_cdf = pd.read_csv('newCafeData.csv')
new_cdf
# Out:
#          메뉴    가격   할인율  칼로리   할인된가격  원두
# 0     아메리카노  3500  0.30   10  2450.0 NaN
# 1      카페라떼  4000  0.40  100  2400.0 NaN
# 2  자바칩프라푸치노  6000  0.20  555  4800.0 NaN
# 3   자몽허니블랙티  5500  0.10  175  4950.0 NaN
# 4   말차프라푸치노  6000  0.25  340  4500.0 NaN

# %% [markdown]
# ## Quiz

# %%
# 주어진 데이터 : 책 5권 -> 책이름, 가격, 할인율, 리뷰수
data = {
    "책이름" : ['정의란 무엇인가', '울어도 괜찮아', '백설공주와 일곱난쟁이', '피노키오', '제인에어'],
    "가격" : [10500, 8800, 3500, 4000, 9500],
    "할인율" : [0.3, 0.1, 0.25, 0.5, 0.3],
    "리뷰수" : [4400, 30, 10500, 8660, 5400],
}

# 원본 데이터를 데이터프레임화
bookdf = pd.DataFrame(data)

# 데이터프레임 csv파일로 저장하기
bookdf.to_csv("bookData.csv", index=False)





# data = {
#     "메뉴":['아메리카노', '카페라떼', '카페모카', '바닐라콜드브루'],
#     "가격":[4100, 4600, 4600, 5100],
#     "할인율":['0.5', '0.1', '0.2', '0.3'],
#     "칼로리":[10,180,420,320],
# }
# df = pd.DataFrame(data)
# df

# %%
# df.info()

# 내가 만든 데이터 프레임 정보 조회
bookdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   책이름     5 non-null      object
#  1   가격      5 non-null      int64
#  2   할인율     5 non-null      float64
#  3   리뷰수     5 non-null      int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 288.0+ bytes

# %% [markdown]
# **1. 이벤트가 컬럼 만들기**
# - 원 가격의 50% 할인을 적용한 이벤트가격

# %%
# df['이벤트가'] = df['가격'] * 0.5
# df


# # 원 가격의 50%할인 적용한 이벤트 가격 칼럼 추가
# bookdf['이벤트가격'] = 0
# bookdf

bookdf['이벤트가격'] = bookdf['가격']*0.5
bookdf
# Out:
#            책이름     가격   할인율    리뷰수   이벤트가격
# 0     정의란 무엇인가  10500  0.30   4400  5250.0
# 1      울어도 괜찮아   8800  0.10     30  4400.0
# 2  백설공주와 일곱난쟁이   3500  0.25  10500  1750.0
# 3         피노키오   4000  0.50   8660  2000.0
# 4         제인에어   9500  0.30   5400  4750.0

# %% [markdown]
# **2. 할인가 컬럼 만들기**
# - 할인을 적용한 할인가격

# %%
# df['할인율'] = df['할인율'].astype('float')
# df['할인가'] = df['가격'] * (1-df['할인율'])
# df


# 할인율을 적용한 할인가 가격 칼럼 만들기
bookdf['할인가'] = bookdf['가격']*(1-bookdf['할인율'])

bookdf
# Out:
#            책이름     가격   할인율    리뷰수   이벤트가격     할인가
# 0     정의란 무엇인가  10500  0.30   4400  5250.0  7350.0
# 1      울어도 괜찮아   8800  0.10     30  4400.0  7920.0
# 2  백설공주와 일곱난쟁이   3500  0.25  10500  1750.0  2625.0
# 3         피노키오   4000  0.50   8660  2000.0  2000.0
# 4         제인에어   9500  0.30   5400  4750.0  6650.0

# %% [markdown]
# **3. 컬럼 삭제**
# - 칼로리 컬럼 삭제

# %%
# df = df.drop('칼로리', axis=1)

# 리뷰수 칼럼 삭제
# bookdf = bookdf.drop('리뷰수', axis=1)
bookdf

#리뷰수 칼럼 다시 추가하기
bookdf['리뷰수'] = [4400, 30, 10500, 8660, 5400]
bookdf
# Out:
#            책이름     가격   할인율   이벤트가격     할인가    리뷰수
# 0     정의란 무엇인가  10500  0.30  5250.0  7350.0   4400
# 1      울어도 괜찮아   8800  0.10  4400.0  7920.0     30
# 2  백설공주와 일곱난쟁이   3500  0.25  1750.0  2625.0  10500
# 3         피노키오   4000  0.50  2000.0  2000.0   8660
# 4         제인에어   9500  0.30  4750.0  6650.0   5400

# %%
# df
# Out:
#         메뉴    가격  할인율    이벤트가     할인가
# 0    아메리카노  4100  0.5  2050.0  2050.0
# 1     카페라떼  4600  0.1  2300.0  4140.0
# 2     카페모카  4600  0.2  2300.0  3680.0
# 3  바닐라콜드브루  5100  0.3  2550.0  3570.0

# %% [markdown]
# # 데이터 핸들링을 위한 판다스 기초2

# %% [markdown]
# ## 인덱싱/슬라이싱

# %%
# 학습 전 실행: csv파일 (data.csv) 생성
# import pandas as pd
# data = {
#     "메뉴":['아메리카노','카페라떼','카페모카', '바닐라라떼', '녹차', '초코라떼', '바닐라콜드브루'],
#     "가격":[4100, 4600, 4600, 5100, 4100, 5000, 5100],
#     "할인율":[0.5, 0.1, 0.2, 0.3, 0, 0, 0],
#     "칼로리":[10, 180, 420, 320, 20, 500, 400],
# }
# data = pd.DataFrame(data)
# data.to_csv('data.csv', index=False)


# csv파일 생성하기 => 스타벅스 카페메뉴 (메뉴, 가격, 할인율, 칼로리)
import pandas as pd
data = {
    "메뉴" : ['아메리카노', '자바칩프라푸치노', '얼그레이티', '자몽허니블랙티', '시나몬초코라떼', '말차프라푸치노', '히비스커스티', '돌체라떼'],
    "가격" : [4500, 6800, 5000, 5800, 5500, 6300, 5500, 7000],
    "할인율" : [0.3, 0.25, 0.15, 0.2, 0.3, 0.45, 0.1, 0.5],
    "칼로리" : [10, 680, 0, 175, 550, 380, 5, 500],
}

stardf = pd.DataFrame(data)
stardf
stardf.to_csv("starbucks.csv", index='False')

# %%
# 데이터 불러오기
# df = pd.read_csv('data.csv')
# df

# cdf

stardf
# Out:
#          메뉴    가격   할인율  칼로리
# 0     아메리카노  4500  0.30   10
# 1  자바칩프라푸치노  6800  0.25  680
# 2     얼그레이티  5000  0.15    0
# 3   자몽허니블랙티  5800  0.20  175
# 4   시나몬초코라떼  5500  0.30  550
# 5   말차프라푸치노  6300  0.45  380
# 6    히비스커스티  5500  0.10    5
# 7      돌체라떼  7000  0.50  500

# %% [markdown]
# ### loc
# - 인덱스 명
# - 인덱스 명(범위), 컬럼 명(범위)

# %%
# 인덱싱 (행 전체)
# 아메리카노
# df.loc[0]

# 행전체 인덱싱 -> 자바칩
stardf.drop(0, axis=0).iloc[0]
# Out:
# 메뉴     자바칩프라푸치노
# 가격         6800
# 할인율        0.25
# 칼로리         680
# Name: 1, dtype: object

# %%
# 슬라이싱 (컬럼 전체)
# 가격
# df.loc[:, "가격"]

# stardf
# 메뉴이름 칼럼 전체 슬라이싱
# stardf.loc[:,"메뉴"]

# 1번 행 조회
# stardf.loc[1]

# 메뉴 열 조회
stardf.loc[:, "메뉴"]
# Out:
# 0       아메리카노
# 1    자바칩프라푸치노
# 2       얼그레이티
# 3     자몽허니블랙티
# 4     시나몬초코라떼
# 5     말차프라푸치노
# 6      히비스커스티
# 7        돌체라떼
# Name: 메뉴, dtype: object

# %%
# 슬라이싱
# 카페라떼 가격
# df.loc[1, "가격"]

# 슬라이싱
# 자바칩 가격만 조회
# stardf
stardf.loc[1, "가격"]
# Out:
# 6800

# %%
# df.head()
stardf
# Out:
#          메뉴    가격   할인율  칼로리
# 0     아메리카노  4500  0.30   10
# 1  자바칩프라푸치노  6800  0.25  680
# 2     얼그레이티  5000  0.15    0
# 3   자몽허니블랙티  5800  0.20  175
# 4   시나몬초코라떼  5500  0.30  550
# 5   말차프라푸치노  6300  0.45  380
# 6    히비스커스티  5500  0.10    5
# 7      돌체라떼  7000  0.50  500

# %%
# 슬라이싱
# 카페모카 메뉴와 가격
# df.loc[2, '메뉴':'가격']

# 얼그레이티 메유, 가격, 할인율
stardf.loc[2, '메뉴' : '할인율']
# Out:
# 메뉴     얼그레이티
# 가격      5000
# 할인율     0.15
# Name: 2, dtype: object

# %%
# 슬라이싱
# 카페모카 메뉴와 칼로리
# df.loc[2, ['메뉴', '칼로리']]

# 히비스커스티 메뉴, 할인율만 조회
# stardf.loc[6, ['메뉴', '할인율']]

stardf
# Out:
#          메뉴    가격   할인율  칼로리
# 0     아메리카노  4500  0.30   10
# 1  자바칩프라푸치노  6800  0.25  680
# 2     얼그레이티  5000  0.15    0
# 3   자몽허니블랙티  5800  0.20  175
# 4   시나몬초코라떼  5500  0.30  550
# 5   말차프라푸치노  6300  0.45  380
# 6    히비스커스티  5500  0.10    5
# 7      돌체라떼  7000  0.50  500

# %%
# 슬라이싱
# 카페라떼, 카페모카 메뉴와 가격
# df.loc[1:2, '메뉴':'가격']

# 시나몬~돌체라떼, 메뉴~가격
# stardf.loc[4:, '메뉴':'가격']

# 시나몬이랑 히비스커스의 메뉴, 할인가 조회
stardf.loc[[4, 6], ['메뉴', '할인율']]
# Out:
#         메뉴  할인율
# 4  시나몬초코라떼  0.3
# 6   히비스커스티  0.1

# %% [markdown]
# ### iloc
# - 인덱스 번호
# - 인덱스 번호(범위), 컬럼 번호(범위)

# %%
# 데이터 보기
# df.head()

stardf

# 아메리카노 삭제
# stardf = stardf.drop(0, axis = 0)
# Out:
#          메뉴    가격   할인율  칼로리
# 1  자바칩프라푸치노  6800  0.25  680
# 2     얼그레이티  5000  0.15    0
# 3   자몽허니블랙티  5800  0.20  175
# 4   시나몬초코라떼  5500  0.30  550
# 5   말차프라푸치노  6300  0.45  380
# 6    히비스커스티  5500  0.10    5
# 7      돌체라떼  7000  0.50  500

# %%
# 인덱싱 (행 전체)
# 아메리카노
# df.iloc[0]

# 얼그레이티 행 전체 조회 iloc 사용
stardf.iloc[1]
# Out:
# 메뉴     얼그레이티
# 가격      5000
# 할인율     0.15
# 칼로리        0
# Name: 2, dtype: object

# %%
# 슬라이싱 (컬럼 전체)
# 가격
# df.iloc[:, 1]

#칼로리 열 전체 저회
stardf.iloc[:, 3]
# Out:
# 1    680
# 2      0
# 3    175
# 4    550
# 5    380
# 6      5
# 7    500
# Name: 칼로리, dtype: int64

# %%
# df.head()

stardf
# Out:
#          메뉴    가격   할인율  칼로리
# 1  자바칩프라푸치노  6800  0.25  680
# 2     얼그레이티  5000  0.15    0
# 3   자몽허니블랙티  5800  0.20  175
# 4   시나몬초코라떼  5500  0.30  550
# 5   말차프라푸치노  6300  0.45  380
# 6    히비스커스티  5500  0.10    5
# 7      돌체라떼  7000  0.50  500

# %%
# 슬라이싱
# 카페모카 메뉴와 가격
# df.iloc[2, 0:2]

# 자허블 메뉴~ 할인율 조회
# stardf.iloc[2, 0:3]

stardf
# Out:
#          메뉴    가격   할인율  칼로리
# 1  자바칩프라푸치노  6800  0.25  680
# 2     얼그레이티  5000  0.15    0
# 3   자몽허니블랙티  5800  0.20  175
# 4   시나몬초코라떼  5500  0.30  550
# 5   말차프라푸치노  6300  0.45  380
# 6    히비스커스티  5500  0.10    5
# 7      돌체라떼  7000  0.50  500

# %%
# 슬라이싱 (카페라떼와 카페모카의 전체 데이터)
# df.iloc[1:3]

#얼그레이티, 말차프, 돌체라떼 전체 데이터 조회
# stardf.iloc[[1,6,4]]

# 자허블~ 히비스커스 전체 데이터 조히
stardf.iloc[1:6]

stardf
# Out:
#          메뉴    가격   할인율  칼로리
# 1  자바칩프라푸치노  6800  0.25  680
# 2     얼그레이티  5000  0.15    0
# 3   자몽허니블랙티  5800  0.20  175
# 4   시나몬초코라떼  5500  0.30  550
# 5   말차프라푸치노  6300  0.45  380
# 6    히비스커스티  5500  0.10    5
# 7      돌체라떼  7000  0.50  500

# %% [markdown]
# ## 데이터 추가

# %%
# 결측값으로 추가, 원두 컬럼을 만들고 결측값(NaN)으로 대입
# import numpy as np
# df['원두'] = np.nan
# df

# 결측값 원산지 추가
import numpy as np
stardf['원산지'] = np.nan
stardf
# Out:
#          메뉴    가격   할인율  칼로리  원산지
# 1  자바칩프라푸치노  6800  0.25  680  NaN
# 2     얼그레이티  5000  0.15    0  NaN
# 3   자몽허니블랙티  5800  0.20  175  NaN
# 4   시나몬초코라떼  5500  0.30  550  NaN
# 5   말차프라푸치노  6300  0.45  380  NaN
# 6    히비스커스티  5500  0.10    5  NaN
# 7      돌체라떼  7000  0.50  500  NaN

# %%
# 아메리카노의 원두는 '콜롬비아' 데이터 추가
# df.loc[0, "원두"] = '콜롬비아'
# df

# 얼그레이랑 히비스커스 원산지 '유럽' 데이터 추가
stardf.loc[[2, 6], "원산지"] = '유럽'
stardf
# Out:
#          메뉴    가격   할인율  칼로리  원산지
# 1  자바칩프라푸치노  6800  0.25  680  NaN
# 2     얼그레이티  5000  0.15    0   유럽
# 3   자몽허니블랙티  5800  0.20  175  NaN
# 4   시나몬초코라떼  5500  0.30  550  NaN
# 5   말차프라푸치노  6300  0.45  380  NaN
# 6    히비스커스티  5500  0.10    5   유럽
# 7      돌체라떼  7000  0.50  500  NaN

# %%
# 리스트 형태로 데이터(행) 추가
# df.loc['시즌'] = ['크리스마스라떼', 6000, 0, 500, '한국']
# df

# 리스트 형태 데이터 추가
stardf.loc['이벤트음료'] = ['한라산생수', 3000, 0, 0, '제주도']
stardf
# Out:
#              메뉴    가격   할인율  칼로리  원산지
# 1      자바칩프라푸치노  6800  0.25  680  NaN
# 2         얼그레이티  5000  0.15    0   유럽
# 3       자몽허니블랙티  5800  0.20  175  NaN
# 4       시나몬초코라떼  5500  0.30  550  NaN
# 5       말차프라푸치노  6300  0.45  380  NaN
# 6        히비스커스티  5500  0.10    5   유럽
# 7          돌체라떼  7000  0.50  500  NaN
# 이벤트음료     한라산생수  3000  0.00    0  제주도

# %%
# 딕셔너리 형태로 데이터(행) 추가
# df.loc[7] = {'메뉴':'에소프레소', '가격':2000, '칼로리':10}
# df

# 딕셔너리 형태로 행 추가
stardf.loc[10] = {
    '메뉴' : '페퍼민트차',
    '가격' : 4500,
    '칼로리' : 0
  }

stardf
# Out:
#              메뉴    가격   할인율  칼로리  원산지
# 1      자바칩프라푸치노  6800  0.25  680  NaN
# 2         얼그레이티  5000  0.15    0   유럽
# 3       자몽허니블랙티  5800  0.20  175  NaN
# 4       시나몬초코라떼  5500  0.30  550  NaN
# 5       말차프라푸치노  6300  0.45  380  NaN
# 6        히비스커스티  5500  0.10    5   유럽
# 7          돌체라떼  7000  0.50  500  NaN
# 이벤트음료     한라산생수  3000  0.00    0  제주도
# 10        페퍼민트차  4500   NaN    0  NaN

# %% [markdown]
# ## 소팅

# %%
# 데이터 보기
# df

stardf
# Out:
#              메뉴    가격   할인율  칼로리  원산지
# 1      자바칩프라푸치노  6800  0.25  680  NaN
# 2         얼그레이티  5000  0.15    0   유럽
# 3       자몽허니블랙티  5800  0.20  175  NaN
# 4       시나몬초코라떼  5500  0.30  550  NaN
# 5       말차프라푸치노  6300  0.45  380  NaN
# 6        히비스커스티  5500  0.10    5   유럽
# 7          돌체라떼  7000  0.50  500  NaN
# 이벤트음료     한라산생수  3000  0.00    0  제주도
# 10        페퍼민트차  4500   NaN    0  NaN

# %%
# df = df.drop("시즌", axis=0)
# df

# 소팅 전에 이벤트 음료 삭제
# stardf = stardf.drop("이벤트음료", axis=0)
stardf
# Out:
#           메뉴    가격   할인율  칼로리  원산지
# 1   자바칩프라푸치노  6800  0.25  680  NaN
# 2      얼그레이티  5000  0.15    0   유럽
# 3    자몽허니블랙티  5800  0.20  175  NaN
# 4    시나몬초코라떼  5500  0.30  550  NaN
# 5    말차프라푸치노  6300  0.45  380  NaN
# 6     히비스커스티  5500  0.10    5   유럽
# 7       돌체라떼  7000  0.50  500  NaN
# 10     페퍼민트차  4500   NaN    0  NaN

# %%
# 인덱스 기준 (기본값 ascending=True)
# df.sort_index(ascending=False)

# 인덱스 기준 내림차순
stardf.sort_index(ascending=False)
# Out:
#           메뉴    가격   할인율  칼로리  원산지
# 10     페퍼민트차  4500   NaN    0  NaN
# 7       돌체라떼  7000  0.50  500  NaN
# 6     히비스커스티  5500  0.10    5   유럽
# 5    말차프라푸치노  6300  0.45  380  NaN
# 4    시나몬초코라떼  5500  0.30  550  NaN
# 3    자몽허니블랙티  5800  0.20  175  NaN
# 2      얼그레이티  5000  0.15    0   유럽
# 1   자바칩프라푸치노  6800  0.25  680  NaN

# %%
# 값 기준 (기본값 ascending=True)
# 메뉴 기준 정렬
# df.sort_values('메뉴',ascending=False)


# 가격 기준 오름차순
stardf.sort_values('가격')
# Out:
#           메뉴    가격   할인율  칼로리  원산지
# 10     페퍼민트차  4500   NaN    0  NaN
# 2      얼그레이티  5000  0.15    0   유럽
# 4    시나몬초코라떼  5500  0.30  550  NaN
# 6     히비스커스티  5500  0.10    5   유럽
# 3    자몽허니블랙티  5800  0.20  175  NaN
# 5    말차프라푸치노  6300  0.45  380  NaN
# 1   자바칩프라푸치노  6800  0.25  680  NaN
# 7       돌체라떼  7000  0.50  500  NaN

# %%
# 가격과 메뉴 기준 정렬
# df = df.sort_values(['가격', '메뉴'],ascending=[False, True])
# df

# 가격과 할인율 기준 정렬 (오름, 내림)
stardf.sort_values(['가격', '할인율'], ascending=[True, False])

stardf.loc[4, "가격"] = 5000

stardf = stardf.sort_values(['가격', '할인율'], ascending=[True,False])

stardf
# Out:
#           메뉴    가격   할인율  칼로리  원산지
# 10     페퍼민트차  4500   NaN    0  NaN
# 4    시나몬초코라떼  5000  0.30  550  NaN
# 2      얼그레이티  5000  0.15    0   유럽
# 6     히비스커스티  5500  0.10    5   유럽
# 3    자몽허니블랙티  5800  0.20  175  NaN
# 5    말차프라푸치노  6300  0.45  380  NaN
# 1   자바칩프라푸치노  6800  0.25  680  NaN
# 7       돌체라떼  7000  0.50  500  NaN

# %%
# 인덱스 새로 만들기 drop=True
# df.reset_index(drop=True)

# 인덱스 새로 생성
stardf.reset_index(drop = True)
# Out:
#          메뉴    가격   할인율  칼로리  원산지
# 0     페퍼민트차  4500   NaN    0  NaN
# 1   시나몬초코라떼  5000  0.30  550  NaN
# 2     얼그레이티  5000  0.15    0   유럽
# 3    히비스커스티  5500  0.10    5   유럽
# 4   자몽허니블랙티  5800  0.20  175  NaN
# 5   말차프라푸치노  6300  0.45  380  NaN
# 6  자바칩프라푸치노  6800  0.25  680  NaN
# 7      돌체라떼  7000  0.50  500  NaN

# %% [markdown]
# ## Quiz

# %%
# 데이터 프레임 만들기
# data = {
#     "메뉴":['아메리카노','카페라떼','카페모카', '바닐라콜드브루'],
#     "가격":[4100, 4600, 4600, 5100],
#     "할인율":[0.5, 0.1, 0.2, 0.3],
#     "칼로리":[10,180,420,320],
# }
# df = pd.DataFrame(data)
# df.head()
# Out:
#         메뉴    가격  할인율  칼로리
# 0    아메리카노  4100  0.5   10
# 1     카페라떼  4600  0.1  180
# 2     카페모카  4600  0.2  420
# 3  바닐라콜드브루  5100  0.3  320

# %% [markdown]
# **1. 앞에서부터 3개의 데이터만 선택하세요**

# %%
# df.loc[:2]

# stardf.loc[3]
stardf

stardf = stardf.sort_index(ascending=True)
stardf

stardf.loc[:3]
# Out:
#          메뉴    가격   할인율  칼로리  원산지
# 1  자바칩프라푸치노  6800  0.25  680  NaN
# 2     얼그레이티  5000  0.15    0   유럽
# 3   자몽허니블랙티  5800  0.20  175  NaN

# %%
# df.iloc[:3]
# Out:
#       메뉴    가격  할인율  칼로리
# 0  아메리카노  4100  0.5   10
# 1   카페라떼  4600  0.1  180
# 2   카페모카  4600  0.2  420

# %% [markdown]
# **2. 주어진 데이터(df)에서 아래 값을 loc와 iloc을 활용해 데이터 프레임으로 각각 출력하시오**
# - 카페라떼	4600	0.1
# - 카페모카	4600	0.2

# %%
# 아래 값만 출력하시오
# 카페라떼	4600	0.1
# 카페모카	4600	0.2

stardf
# Out:
#           메뉴    가격   할인율  칼로리  원산지
# 1   자바칩프라푸치노  6800  0.25  680  NaN
# 2      얼그레이티  5000  0.15    0   유럽
# 3    자몽허니블랙티  5800  0.20  175  NaN
# 4    시나몬초코라떼  5000  0.30  550  NaN
# 5    말차프라푸치노  6300  0.45  380  NaN
# 6     히비스커스티  5500  0.10    5   유럽
# 7       돌체라떼  7000  0.50  500  NaN
# 10     페퍼민트차  4500   NaN    0  NaN

# %%
# loc
# df.loc[1:2, :'할인율']

stardf.loc[3:4, :'할인율']
# Out:
#         메뉴    가격  할인율
# 3  자몽허니블랙티  5800  0.2
# 4  시나몬초코라떼  5000  0.3

# %%
# iloc
# df.iloc[1:3, :3]
stardf.iloc[2:4, :3]
# Out:
#         메뉴    가격  할인율
# 3  자몽허니블랙티  5800  0.2
# 4  시나몬초코라떼  5000  0.3

# %% [markdown]
# **3. 메뉴 중 가격이 가장 비싼 순으로 정렬해 상위 3개 값을 구하시오**

# %%
data = {
    "메뉴":['아메리카노','카페라떼','카페모카', '바닐라라떼', '녹차', '초코라떼', '바닐라콜드브루'],
    "가격":[4100, 4600, 4600, 5100, 4100, 5000, 5100],
    "할인율":[0.5, 0.1, 0.2, 0.3, 0, 0, 0],
    "칼로리":[10, 180, 420, 320, 20, 500, 400],
}
df = pd.DataFrame(data)

# %%
# df

stardf
# Out:
#           메뉴    가격   할인율  칼로리  원산지
# 1   자바칩프라푸치노  6800  0.25  680  NaN
# 2      얼그레이티  5000  0.15    0   유럽
# 3    자몽허니블랙티  5800  0.20  175  NaN
# 4    시나몬초코라떼  5000  0.30  550  NaN
# 5    말차프라푸치노  6300  0.45  380  NaN
# 6     히비스커스티  5500  0.10    5   유럽
# 7       돌체라떼  7000  0.50  500  NaN
# 10     페퍼민트차  4500   NaN    0  NaN

# %%
# df = df.sort_values('가격', ascending=False)
# df

stardf.sort_values('가격', ascending=False).iloc[:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a72aaa7c83cc> in <cell line: 4>()
#       2 # df
#       3
# ----> 4 stardf.sort_values('가격', ascending=False).iloc[:3]
#
# NameError: name 'stardf' is not defined

# %%
df.iloc[:3]
# Out:
#         메뉴    가격  할인율  칼로리
# 3    바닐라라떼  5100  0.3  320
# 6  바닐라콜드브루  5100  0.0  400
# 5     초코라떼  5000  0.0  500

# %% [markdown]
# # 자주 활용되는 판다스 예제

# %%
# 학습 전 실행: csv파일 (data.csv) 생성
# import pandas as pd
# import numpy as np
# data = {
#     "메뉴":['아메리카노','카페라떼','카페모카', '바닐라라떼', '녹차', '초코라떼', '바닐라콜드브루'],
#     "가격":[4100, 4600, 4600, 5100, 4100, 5000, 5100],
#     "할인율":[0.5, 0.1, 0.2, 0.3, 0, 0, 0],
#     "칼로리":[10, 180, 420, 320, 20, 500, 400],
#     "원두":['콜롬비아', np.NaN, '과테말라', np.NaN, '한국', '콜롬비아', np.NaN],
#     "이벤트가":[1900, 2300, np.NaN, 2600, np.NaN, 3000, 3200],
# }
# data = pd.DataFrame(data)
# data.to_csv('data.csv', index=False)

import pandas as pd
import numpy as np
data = {
    "메뉴" : ['아메리카노', '카페라떼', '카페모카', '바닐라라떼', '녹차', '초코라떼', '바닐라콜드브루'],
    "가격" : [4100, 4600, 4600, 5100, 4100, 5000, 5100],
    "할인율" : [0.5, 0.1, 0.2, 0.3, 0, 0, 0],
    "칼로리" : [10, 180, 420, 320, 20, 500, 400],
    "원두" : ['콜롬롬비아', np.NaN, '과테말라', np.NaN, '한국', '콜롬비아', np.NaN],
    "이벤트가" : [1900, 2300, np.NaN, 2600, np.NaN, 3000, 3200],
}

cdf = pd.DataFrame(data)
cdf

cdf.to_csv("cafeData.csv", index=False)

# %%
# 데이터 불러오기
# df = pd.read_csv("data.csv")
# df

cdf = pd.read_csv("cafeData.csv")
cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10  콜롬롬비아  1900.0
# 1     카페라떼  4600  0.1  180    NaN  2300.0
# 2     카페모카  4600  0.2  420   과테말라     NaN
# 3    바닐라라떼  5100  0.3  320    NaN  2600.0
# 4       녹차  4100  0.0   20     한국     NaN
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400    NaN  3200.0

# %% [markdown]
# ## 조건필터

# %%
# 1개 조건
# 할인율 > 0.2
# cond = df['할인율'] > 0.2
# df[cond]
# df[df['할인율'] > 0.2]

# 조건 : 할인율 0.2보다 큰것만 조회
cond = cdf['할인율'] > 0.2
cdf[cond]

cdf[cdf['할인율'] > 0.2]
# Out:
#       메뉴    가격  할인율  칼로리     원두    이벤트가
# 0  아메리카노  4100  0.5   10  콜롬롬비아  1900.0
# 3  바닐라라떼  5100  0.3  320    NaN  2600.0

# %%
# 2개 이상 일때 (AND)
# 할인율 >= 0.2
# 칼로리 < 400
# cond1 = df['할인율'] >= 0.2
# cond2 = df['칼로리'] < 400
# df[cond1 & cond2]

# 조건 2개 모두 충종해야할 때, 할인율 0초과 & 칼로리 300초과

cond1 = cdf['할인율'] > 0
cond2 = cdf['칼로리'] > 300
cdf[cond1 & cond2]

cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10  콜롬롬비아  1900.0
# 1     카페라떼  4600  0.1  180    NaN  2300.0
# 2     카페모카  4600  0.2  420   과테말라     NaN
# 3    바닐라라떼  5100  0.3  320    NaN  2600.0
# 4       녹차  4100  0.0   20     한국     NaN
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400    NaN  3200.0

# %%
# 2개 이상 일때 (OR)
# 할인율 >= 0.2
# 칼로리 < 400
# cond1 = df['할인율'] >= 0.2
# cond2 = df['칼로리'] < 400
# df[cond1 | cond2]

# 둘중 하나 충족
cond1 = cdf['가격'] >= 4500
cond2 = cdf['칼로리'] <= 10
cdf[cond1 | cond2]

cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10  콜롬롬비아  1900.0
# 1     카페라떼  4600  0.1  180    NaN  2300.0
# 2     카페모카  4600  0.2  420   과테말라     NaN
# 3    바닐라라떼  5100  0.3  320    NaN  2600.0
# 4       녹차  4100  0.0   20     한국     NaN
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400    NaN  3200.0

# %%
# 문자열 1개 조건
# 원두 == 콜롬비아
# cond = df['원두'] == "콜롬비아"
# df[cond]

# 문자열을 조건으로 찾기
cond = cdf['원두'] == '콜롬비아'
cdf[cond]
# Out:
#       메뉴    가격  할인율  칼로리    원두    이벤트가
# 0  아메리카노  4100  0.5   10  콜롬비아  1900.0
# 5   초코라떼  5000  0.0  500  콜롬비아  3000.0

# %%
# 문자열과 숫자 조건 (AND)
# 원두 == 콜롬비아
# 가격 < 4500
# cond1 = df['원두'] == "콜롬비아"
# cond2 = df['가격'] < 4500
# df[cond1 & cond2]

# 문자열 + 숫자 조건
# 원두가 콜롬비아면서 가격이 5000미만

cond1 = cdf['원두'] == '콜롬비아'
cond2 = cdf['가격'] < 5000
cdf[cond1 & cond2]
# Out:
#       메뉴    가격  할인율  칼로리    원두    이벤트가
# 0  아메리카노  4100  0.5   10  콜롬비아  1900.0

# %% [markdown]
# ## 결측치

# %%
# 컬럼별 결측치 확인
# df.isnull().sum()


# 칼럼별 결측치 확인
cdf.isnull()
# 결측치 합계 조회
cdf.isnull().sum()
# Out:
# 메뉴      0
# 가격      0
# 할인율     0
# 칼로리     0
# 원두      3
# 이벤트가    2
# dtype: int64

# %%
# 결측값 채우기
# 원두-> 코스타리카로 채우기
# df['원두'] = df['원두'].fillna('코스타리카')

# 결측값 채우기 - 원두의 결측값을 코스타리카로 채우기
# cdf = cdf['원두'].fillna('코스타리카')

# cdf = pd.read_csv('cafeData.csv')
# cdf

# cdf['원두'].replace('콜롬롬비아', '콜롬비아')

# cdf['원두'] = cdf['원두'].fillna('코스타리카')
# cdf

# cdf = cdf['원두'].replace('콜롬롬비아', '콜롬비아')
# cdf = pd.read_csv("cafeData.csv")
# cdf['원두'] = cdf['원두'].replace('콜롬롬비아', '콜롬비아')
# cdf['원두'] = cdf['원두'].fillna('코스타리카')

cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10   콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180  코스타리카  2300.0
# 2     카페모카  4600  0.2  420   과테말라     NaN
# 3    바닐라라떼  5100  0.3  320  코스타리카  2600.0
# 4       녹차  4100  0.0   20     한국     NaN
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  3200.0

# %%
# df

cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10   콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180  코스타리카  2300.0
# 2     카페모카  4600  0.2  420   과테말라     NaN
# 3    바닐라라떼  5100  0.3  320  코스타리카  2600.0
# 4       녹차  4100  0.0   20     한국     NaN
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  3200.0

# %%
# '이벤트가'컬럼 결측치는 1900으로 결측치 채움
# df['이벤트가'] = df['이벤트가'].fillna(1900)
# df

# 이벤트카 결측치 1900으로 채우기
cdf['이벤트가'] = cdf['이벤트가'].fillna(1900)
cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10   콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180  코스타리카  2300.0
# 2     카페모카  4600  0.2  420   과테말라  1900.0
# 3    바닐라라떼  5100  0.3  320  코스타리카  2600.0
# 4       녹차  4100  0.0   20     한국  1900.0
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  3200.0

# %% [markdown]
# ## 값 변경

# %%
# 데이터 확인
# df.head()

cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10   콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180  코스타리카  2300.0
# 2     카페모카  4600  0.2  420   과테말라  1900.0
# 3    바닐라라떼  5100  0.3  320  코스타리카  2600.0
# 4       녹차  4100  0.0   20     한국  1900.0
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  3200.0

# %%
# 문자 변경 : 아메리카노 -> 룽고, 녹차 -> 그린티
# df.replace('아메리카노', '룽고').replace('녹차','그린티')

cdf.replace('녹차', '그린티').replace('아메리카노', '룽고')
# cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0       룽고  4100  0.5   10   콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180  코스타리카  2300.0
# 2     카페모카  4600  0.2  420   과테말라  1900.0
# 3    바닐라라떼  5100  0.3  320  코스타리카  2600.0
# 4      그린티  4100  0.0   20     한국  1900.0
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  3200.0

# %%
# d = {'아메리카노':'룽고', '녹차':'그린티'}
# df = df.replace(d)

cond = {
    '룽고' : '아메리카노',
    '그린티' : '녹차',
}

cdf = cdf.replace(cond)

# %%
cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10   콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180  코스타리카  2300.0
# 2     카페모카  4600  0.2  420   과테말라  1900.0
# 3    바닐라라떼  5100  0.3  320  코스타리카  2600.0
# 4       녹차  4100  0.0   20     한국  1900.0
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  3200.0

# %%
# 숫자 변경 : 1900 -> 1500
# df = df.replace(1900, 1500)
# df

# cdf = cdf['이벤트가'].replace(1900, 1500)
# cdf = pd.read_csv('cafeData.csv')

# cdf = cdf.replace('콜롬롬비아', '콜롬비아')
# cdf

# cond = cdf['원두'].fillna('코스타리카')

# cdf = pd.read_csv("cafeData.csv")

# cdf = cdf['원두'].replace('콜롬롬비아', '콜롬비아')
# cdf = pd.read_csv('cafeData.csv')

# cdf['원두'] = cdf['원두'].replace('콜롬롬비아', '콜롬비아')
# cdf['원두'] = cdf['원두'].fillna('코스타리카')

# cdf

# cdf['이벤트가'] = cdf['이벤트가'].replace(1900, 1500)

# cdf['이벤트가'] = cdf['이벤트가'].fillna(1500)

cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10   콜롬비아  1500.0
# 1     카페라떼  4600  0.1  180  코스타리카  2300.0
# 2     카페모카  4600  0.2  420   과테말라  1500.0
# 3    바닐라라떼  5100  0.3  320  코스타리카  2600.0
# 4       녹차  4100  0.0   20     한국  1500.0
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  3200.0

# %%
# loc로 값 변경하기
# 바닐라라떼 원두 -> 과테말라로 변경
# df.loc[3, "원두"] = "과테말라"
# df


# 바닐라라떼 원두를 과테말라로 수정
# cdf.loc[3, '원두'] = '과테말라'

cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10   콜롬비아  1500.0
# 1     카페라떼  4600  0.1  180  코스타리카  2300.0
# 2     카페모카  4600  0.2  420   과테말라  1500.0
# 3    바닐라라떼  5100  0.3  320   과테말라  2600.0
# 4       녹차  4100  0.0   20     한국  1500.0
# 5     초코라떼  5000  0.0  500   콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  3200.0

# %%
# 이벤트가 전체 1000으로 변경
# df.loc[:, '이벤트가'] = 1000
# df

# 이벤트가 전체를 1000으로 변경
# cdf.loc[:, '이벤트가'] = 1000

# pd.DataFrame(cdf.loc[0, :])


cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10   콜롬비아  1000.0
# 1     카페라떼  4600  0.1  180  코스타리카  1000.0
# 2     카페모카  4600  0.2  420   과테말라  1000.0
# 3    바닐라라떼  5100  0.3  320   과테말라  1000.0
# 4       녹차  4100  0.0   20     한국  1000.0
# 5     초코라떼  5000  0.0  500   콜롬비아  1000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  1000.0

# %% [markdown]
# ## 내장함수
# - 데이터 핸들링을 위한 판다스 기초1(EDA) 부분에서 일부 내장함수를 학습했고, 그외 함수에 대해 살펴봄

# %%
# 데이터 불러오기
# df = pd.read_csv('data.csv')
# df

cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10   콜롬비아  1000.0
# 1     카페라떼  4600  0.1  180  코스타리카  1000.0
# 2     카페모카  4600  0.2  420   과테말라  1000.0
# 3    바닐라라떼  5100  0.3  320   과테말라  1000.0
# 4       녹차  4100  0.0   20     한국  1000.0
# 5     초코라떼  5000  0.0  500   콜롬비아  1000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  1000.0

# %%
# 카운트 (컬럼) #기본값 axis=0
# df.count()


# 데이터 카운트 -> 기본값 axos = 0 (1: 열, 0: 행)

# cdf.count(axis=1) 열 개수
cdf.count() # 행 개수
# Out:
# 메뉴      7
# 가격      7
# 할인율     7
# 칼로리     7
# 원두      7
# 이벤트가    7
# dtype: int64

# %%
# 카운트 (열)
# df.count(axis=1)
cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10   콜롬비아  1000.0
# 1     카페라떼  4600  0.1  180  코스타리카  1000.0
# 2     카페모카  4600  0.2  420   과테말라  1000.0
# 3    바닐라라떼  5100  0.3  320   과테말라  1000.0
# 4       녹차  4100  0.0   20     한국  1000.0
# 5     초코라떼  5000  0.0  500   콜롬비아  1000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  1000.0

# %%
 # [Tip] 데이터 수 len, shape
# len(df)
# df.shape[0]

# 데이터 수
# cdf
# len(cdf)
# cdf.shape (행, 열)

# 데이터수 조회하기
# cdf.shape[0]
cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10   콜롬비아  1000.0
# 1     카페라떼  4600  0.1  180  코스타리카  1000.0
# 2     카페모카  4600  0.2  420   과테말라  1000.0
# 3    바닐라라떼  5100  0.3  320   과테말라  1000.0
# 4       녹차  4100  0.0   20     한국  1000.0
# 5     초코라떼  5000  0.0  500   콜롬비아  1000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  1000.0

# %%
# 최대값
# df['가격'].max()

# 칼로리 최댓값 조회
cdf['칼로리'].max()
# Out:
# 500

# %%
# 최소값
# df['가격'].min()

cdf['칼로리'].min()
# Out:
# 10

# %%
# 평균
# df['가격'].mean()

# 평귱
cdf['이벤트가'].mean()
# Out:
# 1000.0

# %%
# 중앙값
# df['가격'].median()

cdf['칼로리'].median()
# Out:
# 320.0

# %%
# 합계
# df['가격'].sum()

# 합계
cdf['가격'].sum()
# Out:
# 32600

# %%
# 표준편차
# df['가격'].std()

# 표준편차 std

cdf['가격'].std()
# Out:
# 435.3433237386437

# %%
# 분산
# df['가격'].var()

# 분산 var

cdf['가격'].var()
# Out:
# 189523.8095238095

# %%
# 왜도 skewness
# df['가격'].skew()

# 왜도 skew

cdf['가격'].skew()
# cdf['가격']
# Out:
# -0.3739900475641664

# %%
# 첨도 kurtosis
# df['가격'].kurt()

# 첨도 kurt
# cdf['가격'].kurt()

# 첨도 kurt
cdf['가격'].kurt()
# Out:
# -1.7170778515694067

# %%
# 백분위수
# df['가격'].describe()

# 백분위수
# cdf['가격'].describe()
cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10   콜롬비아  1000.0
# 1     카페라떼  4600  0.1  180  코스타리카  1000.0
# 2     카페모카  4600  0.2  420   과테말라  1000.0
# 3    바닐라라떼  5100  0.3  320   과테말라  1000.0
# 4       녹차  4100  0.0   20     한국  1000.0
# 5     초코라떼  5000  0.0  500   콜롬비아  1000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  1000.0

# %%
# 하위 25% 값
# df['가격'].quantile(.25)

# 하위 25% 이하 데이타
cond = cdf['칼로리'] <= cdf['칼로리'].quantile(.25)
cdf[cond]
# Out:
#       메뉴    가격  할인율  칼로리    원두    이벤트가
# 0  아메리카노  4100  0.5   10  콜롬비아  1000.0
# 4     녹차  4100  0.0   20    한국  1000.0

# %%
# 상위 25% 값
# df['가격'].quantile(.75)

#상위 25%
# cdf['칼로리'].quantile(.75)

cdf[cdf['칼로리'].quantile(.75) <= cdf['칼로리']]
# Out:
#      메뉴    가격  할인율  칼로리    원두    이벤트가
# 2  카페모카  4600  0.2  420  과테말라  1000.0
# 5  초코라떼  5000  0.0  500  콜롬비아  1000.0

# %%
# 하위 25% 데이터
cond = df['가격'].quantile(.25) > df['가격']
df[cond]
# Out:
#       메뉴    가격  할인율  칼로리    원두    이벤트가
# 0  아메리카노  4100  0.5   10  콜롬비아  1900.0
# 4     녹차  4100  0.0   20    한국     NaN

# %%
# 상위 25% 데이터
cond = df['가격'].quantile(.75) < df['가격']
df[cond]
# Out:
#         메뉴    가격  할인율  칼로리   원두    이벤트가
# 3    바닐라라떼  5100  0.3  320  NaN  2600.0
# 6  바닐라콜드브루  5100  0.0  400  NaN  3200.0

# %%
# 최빈값 구하기
# df['원두'].mode()[0]

# 원두 최빈값
# cdf

cdf['원두'].mode()
# Out:
# '과테말라'

# %% [markdown]
# **심화학습(apply함수)**

# %%
# 데이터 확인
# df

cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가
# 0    아메리카노  4100  0.5   10   콜롬비아  1000.0
# 1     카페라떼  4600  0.1  180  코스타리카  1000.0
# 2     카페모카  4600  0.2  420   과테말라  1000.0
# 3    바닐라라떼  5100  0.3  320   과테말라  1000.0
# 4       녹차  4100  0.0   20     한국  1000.0
# 5     초코라떼  5000  0.0  500   콜롬비아  1000.0
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  1000.0

# %%
# apply 예시
# def cal(x):
#     if x >= 300:
#         return "No"
#     else:
#         return "Yes"

# df['칼로리'].apply(cal)


# 칼로리가 300이 이면 NO 아니면 YES
def cal(x):
  if x >= 300:
    return "NO"
  else:
    return "YES"

pd.DataFrame(cdf['칼로리'].apply(cal))
# Out:
#    칼로리
# 0  YES
# 1  YES
# 2   NO
# 3   NO
# 4  YES
# 5   NO
# 6   NO

# %%
# apply 적용해서 새로운 컬럼 생성 (칼로리 컬럼 활용)
# df['먹어도될까요'] = df['칼로리'].apply(cal)
# df


# apply 적용해서 새로운 칼럼
cdf['먹어도 돼??'] = cdf['칼로리'].apply(cal)
cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가 먹어도 돼??
# 0    아메리카노  4100  0.5   10   콜롬비아  1000.0     YES
# 1     카페라떼  4600  0.1  180  코스타리카  1000.0     YES
# 2     카페모카  4600  0.2  420   과테말라  1000.0      NO
# 3    바닐라라떼  5100  0.3  320   과테말라  1000.0      NO
# 4       녹차  4100  0.0   20     한국  1000.0     YES
# 5     초코라떼  5000  0.0  500   콜롬비아  1000.0      NO
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  1000.0      NO

# %% [markdown]
# ## 그룹핑

# %%
# 원두 기준, 평균
# 코랩에서 판다스 버전이 업데이트되어 일부 함수에 `numeric_only=True` 를 설정해야 합니다.
# 이 설정은 데이터프레임에서 숫자 형태의 데이터만 선택하도록 지정합니다. (단, 시험환경 버전은 설정 필요 없음)
# df.groupby('원두').mean()
# df.groupby('원두').mean(numeric_only=True)

# cdf
# cdf.groupby('원두').mean(numeric_only=True)

cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가 먹어도 돼??
# 0    아메리카노  4100  0.5   10   콜롬비아  1000.0     YES
# 1     카페라떼  4600  0.1  180  코스타리카  1000.0     YES
# 2     카페모카  4600  0.2  420   과테말라  1000.0      NO
# 3    바닐라라떼  5100  0.3  320   과테말라  1000.0      NO
# 4       녹차  4100  0.0   20     한국  1000.0     YES
# 5     초코라떼  5000  0.0  500   콜롬비아  1000.0      NO
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  1000.0      NO

# %%
# 원두와 할인율 기준, 평균
# 코랩에서 판다스 버전이 업데이트되어 일부 함수에 `numeric_only=True` 를 설정해야 합니다.
# 이 설정은 데이터프레임에서 숫자 형태의 데이터만 선택하도록 지정합니다. (단, 시험환경 버전은 설정 필요 없음)
# df.groupby(['원두', '할인율']).mean()
# df.groupby(['원두', '할인율']).mean(numeric_only=True)

#  원두 및 할인 율 기준 그룹화하여 평균 내기
cdf.groupby(['원두', '할인율']).mean(numeric_only = True)
# Out:
#                가격    칼로리    이벤트가
# 원두    할인율
# 과테말라  0.2  4600.0  420.0  1000.0
#       0.3  5100.0  320.0  1000.0
# 코스타리카 0.0  5100.0  400.0  1000.0
#       0.1  4600.0  180.0  1000.0
# 콜롬비아  0.0  5000.0  500.0  1000.0
#       0.5  4100.0   10.0  1000.0
# 한국    0.0  4100.0   20.0  1000.0

# %%
# 원두와 할인율 기준, 가격 평균
# df.groupby(['원두', '할인율'])['가격'].mean()

# 원두와 활인율 기준 그룹화후 가격만 평균내기
pd.DataFrame(cdf.groupby(['원두', '할인율'])['가격'].mean())
# Out:
#                가격
# 원두    할인율
# 과테말라  0.2  4600.0
#       0.3  5100.0
# 코스타리카 0.0  5100.0
#       0.1  4600.0
# 콜롬비아  0.0  5000.0
#       0.5  4100.0
# 한국    0.0  4100.0

# %%
# 원두와 할인율 기준, 가격 평균 -> 데이터 프레임 형태
pd.DataFrame(df.groupby(['원두', '할인율'])['가격'].mean())
# Out:
#               가격
# 원두   할인율
# 과테말라 0.2  4600.0
# 콜롬비아 0.0  5000.0
#      0.5  4100.0
# 한국   0.0  4100.0

# %%
# 1개 인덱스 형태로 리셋
# df.groupby(['원두', '할인율']).mean().reset_index()
# df.groupby(['원두', '할인율']).mean(numeric_only=True).reset_index()

# 1개 인덱스 형태로
cdf.groupby(['원두', '할인율']).mean(numeric_only=True).reset_index()
# Out:
#       원두  할인율      가격    칼로리    이벤트가
# 0   과테말라  0.2  4600.0  420.0  1000.0
# 1   과테말라  0.3  5100.0  320.0  1000.0
# 2  코스타리카  0.0  5100.0  400.0  1000.0
# 3  코스타리카  0.1  4600.0  180.0  1000.0
# 4   콜롬비아  0.0  5000.0  500.0  1000.0
# 5   콜롬비아  0.5  4100.0   10.0  1000.0
# 6     한국  0.0  4100.0   20.0  1000.0

# %% [markdown]
# ## Quiz

# %%
# 학습 전 실행: csv파일 (data.csv) 생성
import pandas as pd
import numpy as np
data = {
    "메뉴":['아메리카노','카페라떼','카페모카', '바닐라라떼', '녹차', '초코라떼', '바닐라콜드브루'],
    "가격":[4100, 4600, 4600, 5100, 4100, 5000, 5100],
    "할인율":[0.5, 0.1, 0.2, 0.3, 0, 0, 0],
    "칼로리":[10, 180, 420, 320, 20, 500, 400],
    "원두":['콜롬비아', np.NaN, '과테말라', np.NaN, '한국', '콜롬비아', np.NaN],
    "이벤트가":[1900, 2300, np.NaN, 2600, np.NaN, 3000, 3200],
}
data = pd.DataFrame(data)
data.to_csv('data.csv', index=False)

# %%
# 데이터 불러오기
# df = pd.read_csv('data.csv')
# df

df = pd.read_csv('data.csv')
df
# Out:
#         메뉴    가격  할인율  칼로리    원두    이벤트가
# 0    아메리카노  4100  0.5   10  콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180   NaN  2300.0
# 2     카페모카  4600  0.2  420  과테말라     NaN
# 3    바닐라라떼  5100  0.3  320   NaN  2600.0
# 4       녹차  4100  0.0   20    한국     NaN
# 5     초코라떼  5000  0.0  500  콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400   NaN  3200.0

# %% [markdown]
# **1. '이벤트가' 컬럼 결측치는 이벤트가격 데이터 중 최소값으로 결측치 채움**

# %%
# min_price = df['이벤트가'].min()
# df['이벤트가'] = df['이벤트가'].fillna(min_price)
# df


# df['이벤트가'] = df['이벤트가'].fillna(df['이벤트가'].min())
# df
# Out:
#         메뉴    가격  할인율  칼로리    원두    이벤트가
# 0    아메리카노  4100  0.5   10  콜롬비아  1900.0
# 1     카페라떼  4600  0.1  180   NaN  2300.0
# 2     카페모카  4600  0.2  420  과테말라  1900.0
# 3    바닐라라떼  5100  0.3  320   NaN  2600.0
# 4       녹차  4100  0.0   20    한국  1900.0
# 5     초코라떼  5000  0.0  500  콜롬비아  3000.0
# 6  바닐라콜드브루  5100  0.0  400   NaN  3200.0

# %% [markdown]
# **2. '원두' 컬럼 결측치는 원두 데이터 중 최빈값으로 결측치 채움**

# %%
# f = df['원두'].mode()[0]
# df['원두'] = df['원두'].fillna(f)
# df
# cdf['원두'].mode()
# cdf['원두'] = cdf['원두'].fillna(cdf['원두'].mode()[0])

cdf
# Out:
#         메뉴    가격  할인율  칼로리     원두    이벤트가 먹어도 돼??
# 0    아메리카노  4100  0.5   10   콜롬비아  1000.0     YES
# 1     카페라떼  4600  0.1  180  코스타리카  1000.0     YES
# 2     카페모카  4600  0.2  420   과테말라  1000.0      NO
# 3    바닐라라떼  5100  0.3  320   과테말라  1000.0      NO
# 4       녹차  4100  0.0   20     한국  1000.0     YES
# 5     초코라떼  5000  0.0  500   콜롬비아  1000.0      NO
# 6  바닐라콜드브루  5100  0.0  400  코스타리카  1000.0      NO

# %% [markdown]
# **3. 가격이 5000 이상인 데이터의 수를 구하시오**

# %%
# cond = df['가격'] >= 5000
# len(df[cond])

# cdf[cdf['가격'] >= 5000].shape[0]

len(cdf[cdf['가격'] >= 5000])
# Out:
# 3
